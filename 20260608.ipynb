# %% [markdown]
# <a href="https://colab.research.google.com/github/raiforPython/python_learning/blob/python%E8%AA%8D%E5%AE%9A%E5%9F%BA%E7%A4%8E%E8%A9%A6%E9%A8%93%E5%AF%BE%E7%AD%96/20260608.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data=[]
for i in [1,2,3]:
    for j in [1,2]:
        if i ! = j:
        data.append((i,j))
print(data)
# Out:
#   File "/tmp/ipykernel_14403/706990941.py", line 4
#     if i ! = j:
#          ^
# SyntaxError: invalid syntax

# %%
data=[]
for i in [1,2,3]:
    for j in [1,2]:
        if i != j:
           data.append((i,j))
print(data)
# Out:
# [(1, 2), (2, 1), (3, 1), (3, 2)]

# %%
data=[]
for i in [1,2,3]:
    for j in [1,2]:
        if i == j:
            data.append((i,j))
print(data)
# Out:
# [(1, 1), (2, 2)]

# %%
a = ["dog","cat","penguin","elephant"]

del a[2]
print(a)
# Out:
# ['dog', 'cat', 'elephant']

# %%
a = ["dog","cat","penguin","elephant"]

a.remove("cat")
print(a)
# Out:
# ['dog', 'penguin', 'elephant']
