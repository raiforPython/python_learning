# %% [markdown]
# <a href="https://colab.research.google.com/github/raiforPython/python_learning/blob/chapter_7/7-7_%E7%B7%B4%E7%BF%92%E5%95%8F%E9%A1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
    # 練習7-4
# 次の機能を持つプログラムを、組み込み関数を使ってそれぞれ作成しなさい。ただし、いずれも必ず指定の数値が入力されていることを前提とします。
# (1)入力された3つの整数の内、大きい値を表示する
numbers = [12,5,2,3,26]
print(max(numbers))
# Out:
# 26

# %%
# (2)円周率3.141592について、小数点以下第1位から小数点第5位を四捨五入した値をそれぞれ入力する
import math

print(f'小数点第一位を四捨五入した値は{math.floor}です')

# %%
# (2)円周率3.141592について、小数点以下第1位から小数点第5位を四捨五入した値をそれぞれ入力する
pi = 3.141592
print(f'小数点第1位を四捨五入した値は{round(pi)}です')
# Out:
# 小数点第1位を四捨五入した値は3です

# %%
# (2)円周率3.141592について、小数点以下第1位から小数点第5位を四捨五入した値をそれぞれ入力する
pi = 3.141592

print(f'小数点第1位を四捨五入した値は{round(pi)}です')
print(f'小数点第2位を四捨五入した値は{round(pi),2}です')
# Out:
# 小数点第1位を四捨五入した値は3です
# 小数点第2位を四捨五入した値は(3, 2)です

# %%
# (2)円周率3.141592について、小数点以下第1位から小数点第5位を四捨五入した値をそれぞれ入力する
pi = 3.141592
c = 0
for i in range(5):
    print(f'小数点第{c}位を四捨五入した値は{round(pi,c-1)}です')
    c += 1
# Out:
# 小数点第0位を四捨五入した値は0.0です
# 小数点第1位を四捨五入した値は3.0です
# 小数点第2位を四捨五入した値は3.1です
# 小数点第3位を四捨五入した値は3.14です
# 小数点第4位を四捨五入した値は3.142です

# %%
# (2)円周率3.141592について、小数点以下第1位から小数点第5位を四捨五入した値をそれぞれ入力する
pi = 3.141592
c = 0
for i in range(5):
    print(f'小数点第{c+1}位を四捨五入した値は{round(pi,c)}です')
    c += 1
# Out:
# 小数点第1位を四捨五入した値は3.0です
# 小数点第2位を四捨五入した値は3.1です
# 小数点第3位を四捨五入した値は3.14です
# 小数点第4位を四捨五入した値は3.142です
# 小数点第5位を四捨五入した値は3.1416です

# %%
text = input('何を記録しますか>>')
file = open('sample.txt','a')
file.write(text + '\n')
file.close
# Out:
# 何を記録しますか>>Python認定基礎試験合格！
# <function TextIOWrapper.close()>

# %%
# 練習7-5
file = open('sample.txt','r')
note = open('newnote.txt','w')
for line in file:
    note.write(line)
print(note)
file.close
# Out:
# <_io.TextIOWrapper name='newnote.txt' mode='w' encoding='utf-8'>
# <function TextIOWrapper.close()>

# %%
# 練習7-5
file = open('sample.txt','r')
note = open('newnote.txt','w')
for line in file:
    note.write(line)
print(note)
file.close
note.close
# Out:
# <_io.TextIOWrapper name='newnote.txt' mode='w' encoding='utf-8'>
# <function TextIOWrapper.close()>

# %%
# 練習7-6
from random import randint
print('数当てゲームを始めます。3桁の数を当ててください！')

answer = []
for num in range(3):
    answer.append(randint(0,9))

prediction = []
for numbers in range(3):
    pre = input(f'{numbers + 1}桁目の予想を入力（0～9）>>')
    prediction.append(pre)
# Out:
# 数当てゲームを始めます。3桁の数を当ててください！
# 1桁目の予想を入力（0～9）>>1
# 2桁目の予想を入力（0～9）>>2
# 3桁目の予想を入力（0～9）>>3

# %%
# 練習7-6
from random import randint
print('数当てゲームを始めます。3桁の数を当ててください！')

answer = []
for num in range(3):
    answer.append(randint(0,9))

conti = 1
while conti == 1:
    prediction = []
    for numbers in range(3):
        pre = input(f'{numbers + 1}桁目の予想を入力（0～9）>>')
        prediction.append(pre)

    hit = 0
    for n in range(3):
        if prediction[n] == answer[n]:
            hit += 1

    ball = 0
    if prediction[0] == answer[1]:
        ball += 1
    elif prediction[0] == answer[2]:
        ball += 1

    if prediction[1] == answer[0]:
        ball += 1
    elif prediction[1] == answer[2]:
        ball += 1

    if prediction[2] == answer[0]:
        ball += 1
    elif prediction[2] == answer[1]:
        ball += 1

    if hit == 3:
        print('正解です！')
    else:
        print(f'{hit}ヒット！{ball}ボール！')
        conti = int(input('続けますか？　1：続ける　2：終了>>'))

if conti == 2:
    print('正解を表示します')
    print(answer)
# Out:
# 数当てゲームを始めます。3桁の数を当ててください！
# 1桁目の予想を入力（0～9）>>1
# 2桁目の予想を入力（0～9）>>2
# 3桁目の予想を入力（0～9）>>3
# 0ヒット！0ボール！
# 続けますか？　1：続ける　2：終了>>1
# 1桁目の予想を入力（0～9）>>5
# 2桁目の予想を入力（0～9）>>6
# 3桁目の予想を入力（0～9）>>2
# 0ヒット！0ボール！
# 続けますか？　1：続ける　2：終了>>2
# 正解を表示します
# [7, 7, 0]

# %%
# 練習7-6
from random import randint
print('数当てゲームを始めます。3桁の数を当ててください！')

answer = []
for num in range(3):
    answer.append(randint(0,9))
print(answer)   #プログラム修正のため一時的に実装

conti = 1
while conti == 1:
    prediction = []
    for numbers in range(3):
        pre = input(f'{numbers + 1}桁目の予想を入力（0～9）>>')
        prediction.append(pre)
        print(prediction)

    hit = 0
    for n in range(3):
        if prediction[n] == answer[n]:
            hit =+ 1
            print(prediction[n])

    ball = 0
    if prediction[0] == answer[1]:
        ball =+ 1
    elif prediction[0] == answer[2]:
        ball =+ 1

    if prediction[1] == answer[0]:
        ball =+ 1
    elif prediction[1] == answer[2]:
        ball =+ 1

    if prediction[2] == answer[0]:
        ball =+ 1
    elif prediction[2] == answer[1]:
        ball =+ 1


    if hit == 3:
        print('正解です！')
    else:
        print(f'{hit}ヒット！{ball}ボール！')
        conti = int(input('続けますか？　1：続ける　2：終了>>'))

if conti == 2:
    print('正解を表示します')
    print(answer)
# Out:
# 数当てゲームを始めます。3桁の数を当ててください！
# [8, 8, 8]
# 1桁目の予想を入力（0～9）>>8
# ['8']
# 2桁目の予想を入力（0～9）>>8
# ['8', '8']
# 3桁目の予想を入力（0～9）>>8
# ['8', '8', '8']
# 0ヒット！0ボール！
# 続けますか？　1：続ける　2：終了>>2
# 正解を表示します
# [8, 8, 8]

# %%
# 練習7-6
from random import randint
print('数当てゲームを始めます。3桁の数を当ててください！')

answer = []
for num in range(3):
    answer.append(randint(0,9))
print(answer)   #プログラム修正のため一時的に実装

conti = 1
while conti == 1:
    prediction = []
    for numbers in range(3):
        pre = int(input(f'{numbers + 1}桁目の予想を入力（0～9）>>')) #数値でリストに入れるように工夫
        prediction.append(pre)
        print(prediction)

    hit = 0
    for n in range(3):
        if prediction[n] == answer[n]:
            hit = hit + 1
            print(prediction[n])

    ball = 0
    if prediction[0] == answer[1]:
        ball =+ 1
    elif prediction[0] == answer[2]:
        ball =+ 1

    if prediction[1] == answer[0]:
        ball =+ 1
    elif prediction[1] == answer[2]:
        ball =+ 1

    if prediction[2] == answer[0]:
        ball =+ 1
    elif prediction[2] == answer[1]:
        ball =+ 1


    if hit == 3:
        print('正解です！') #この書き方だと正解したとしても、問答無用でもう一度予想から。間違えない限りループする。。。
    else:
        print(f'{hit}ヒット！{ball}ボール！')
        conti = int(input('続けますか？　1：続ける　2：終了>>'))

if conti == 2:
    print('正解を表示します')
    print(answer)
# Out:
# 数当てゲームを始めます。3桁の数を当ててください！
# [3, 0, 2]
# 1桁目の予想を入力（0～9）>>3
# [3]
# 2桁目の予想を入力（0～9）>>0
# [3, 0]
# 3桁目の予想を入力（0～9）>>2
# [3, 0, 2]
# 3
# 0
# 2
# 正解です！
# 1桁目の予想を入力（0～9）>>2
# [2]
# 2桁目の予想を入力（0～9）>>0
# [2, 0]
# 3桁目の予想を入力（0～9）>>2
# [2, 0, 2]
# 0
# 2
# 2ヒット！1ボール！
# 続けますか？　1：続ける　2：終了>>2
# 正解を表示します
# [3, 0, 2]

# %%
# 練習7-6
from random import randint
print('数当てゲームを始めます。3桁の数を当ててください！')

answer = []
for num in range(3):
    answer.append(randint(0,9))
print(answer)   #プログラム修正のため一時的に実装

conti = 1
while conti == 1:
    prediction = []
    for numbers in range(3):
        pre = int(input(f'{numbers + 1}桁目の予想を入力（0～9）>>')) #数値でリストに入れるように工夫
        prediction.append(pre)
        print(prediction)

    hit = 0
    for n in range(3):
        if prediction[n] == answer[n]:
            hit = hit + 1
            print(prediction[n])

    ball = 0
    if prediction[0] == answer[1]:
        ball =+ 1
    elif prediction[0] == answer[2]:
        ball =+ 1

    if prediction[1] == answer[0]:
        ball =+ 1
    elif prediction[1] == answer[2]:
        ball =+ 1

    if prediction[2] == answer[0]:
        ball =+ 1
    elif prediction[2] == answer[1]:
        ball =+ 1


    if hit == 3:
        print('正解です！') #
        break
    else:
        print(f'{hit}ヒット！{ball}ボール！')
        conti = int(input('続けますか？　1：続ける　2：終了>>'))

if conti == 2:
    print('正解を表示します')
    print(answer)
# Out:
# 数当てゲームを始めます。3桁の数を当ててください！
# [4, 9, 4]
# 1桁目の予想を入力（0～9）>>4
# [4]
# 2桁目の予想を入力（0～9）>>9
# [4, 9]
# 3桁目の予想を入力（0～9）>>4
# [4, 9, 4]
# 4
# 9
# 4
# 正解です！

# %%
# 練習7-6 完成形！
from random import randint
print('数当てゲームを始めます。3桁の数を当ててください！')

answer = []
for num in range(3):
    answer.append(randint(0,9))

conti = 1
while conti == 1:
    prediction = []
    for numbers in range(3):
        pre = int(input(f'{numbers + 1}桁目の予想を入力（0～9）>>'))
        prediction.append(pre)
        print(f'>>{prediction}')

    hit = 0
    for n in range(3):
        if prediction[n] == answer[n]:
            hit = hit + 1

    ball = 0
    if prediction[0] == answer[1]:
        ball = ball + 1
    elif prediction[0] == answer[2]:
        ball = ball + 1

    if prediction[1] == answer[0]:
        ball = ball + 1
    elif prediction[1] == answer[2]:
        ball = ball + 1

    if prediction[2] == answer[0]:
        ball = ball + 1
    elif prediction[2] == answer[1]:
        ball = ball + 1


    if hit == 3:
        print()
        print(f'正解です！（正解は{answer}）')
        break
    else:
        print()
        print(f'{hit}ヒット！{ball}ボール！')
        conti = int(input('続けますか？　1：続ける　2：終了>>'))
        print()

if conti == 2:
    print()
    print('正解を表示します')
    print(answer)
# Out:
# 数当てゲームを始めます。3桁の数を当ててください！
# [8, 7, 5]
# 1桁目の予想を入力（0～9）>>6
# >>[6]
# 2桁目の予想を入力（0～9）>>4
# >>[6, 4]
# 3桁目の予想を入力（0～9）>>2
# >>[6, 4, 2]
#
# 0ヒット！0ボール！
# 続けますか？　1：続ける　2：終了>>1
#
# 1桁目の予想を入力（0～9）>>5
# >>[5]
# 2桁目の予想を入力（0～9）>>6
# >>[5, 6]
# 3桁目の予想を入力（0～9）>>4
# >>[5, 6, 4]
#
# 0ヒット！1ボール！
# 続けますか？　1：続ける　2：終了>>1
#
# 1桁目の予想を入力（0～9）>>8
# >>[8]
# 2桁目の予想を入力（0～9）>>7
# >>[8, 7]
# 3桁目の予想を入力（0～9）>>9
# >>[8, 7, 9]
#
# 2ヒット！0ボール！
# 続けますか？　1：続ける　2：終了>>1
#
# 1桁目の予想を入力（0～9）>>8
# >>[8]
# 2桁目の予想を入力（0～9）>>7
# >>[8, 7]
# 3桁目の予想を入力（0～9）>>5
# >>[8, 7, 5]
#
# 正解です！（正解は[8, 7, 5]）
