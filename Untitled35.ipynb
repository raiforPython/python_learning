# %% [markdown]
# <a href="https://colab.research.google.com/github/raiforPython/python_learning/blob/main/Untitled35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

random.randome()-1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1867/2116142287.py in <cell line: 0>()
#       1 import random
#       2
# ----> 3 random.randome()-1
#
# AttributeError: module 'random' has no attribute 'randome'

# %%
import random

random.random()-1
# Out:
# -0.3122737598298162

# %%
import random

random.random() * 2 - 1
# Out:
# 0.25542743026338477

# %%
import statistics

data = [-1,-1,-1,-1,4]

print(statistics.mean(data))
print(statistics.median(data))
print(statistics.variance(data))
# Out:
# 0
# -1
# 5

# %%
from datetime import datetime

dt=datetime(2000,12,31)
print(dt.strftime('{year}-{month}-{day}'))
# Out:
# {year}-{month}-{day}

# %%
from datetime import datetime

dt=datetime(2000,12,31)
print(dt.strftime("%Y-%m-%d"))
# Out:
# 2000-12-31

# %%
from datetime import datetime

dt=datetime(2000,12,31)
print(dt.strftime("%y-%m-%d"))
# Out:
# 00-12-31

# %%
from datetime import date

today = date.today()
print(today.year, today.month, today.day)
# Out:
# 2026 6 6

# %%
from datetime import datetime

now = datetime.now()
print(now.hour,now.minute,now.second)
# Out:
# 10 18 22
