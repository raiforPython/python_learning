# %% [markdown]
# <a href="https://colab.research.google.com/github/raiforPython/python_learning/blob/python%E8%AA%8D%E5%AE%9A%E5%9F%BA%E7%A4%8E%E8%A9%A6%E9%A8%93%E5%AF%BE%E7%AD%96/20260630.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

x = 9.7
print(math.floor(x))
# Out:
# 9

# %% [markdown]
# import random
#
# random.seed(10)
# print(random.randint(1, 3))

# %%
nums = [3, 1, 4, 2]
result = sorted(nums)
print(result)
# Out:
# [1, 2, 3, 4]

# %%
import os

print(os.path.join("usr", "local", "bin"))
# Out:
# usr/local/bin

# %%
items = ["a", "b", "c"]

for i, v in enumerate(items, start=1):
    print(i, v)
# Out:
# 1 a
# 2 b
# 3 c

# %%
a = [1, 2, 3]
b = ["x", "y"]

for x, y in zip(a, b):
    print(x, y)
# Out:
# 1 x
# 2 y

# %%
values = [0, "", 0]

print(any(values))
# any(values) は 「真とみなせる値が1つでもあれば True」 を返す。
# Out:
# False

# %%
values = [1, "ok", True]

print(all(values))
# Out:
# False

# %%
values = [3, 8, 1, 6]
print(max(values))
# Out:
# 8

# %%
value = 3.14159
print(round(value, 2))
# Out:
# 3.14

# %%
print(divmod(17, 5))
# Out:
# (3, 2)

# %%
data = ["py", [1, 2, 3], "thon"]
print(len(data[1]))
# Out:
# 3

# %%
info = {
    "lang": "Python",
    "versions": [3.7, 3.8, 3.9],
    "creator": {"first": "Guido", "last": "van Rossum"}
}

print(len(info["creator"]))
# Out:
# 2

# %%
items = (
    "py",
    ["a", "b", "c"],
    (1, 2, 3, 4),
    {"x": 10, "y": 20, "z": 30}
)

print(len(items[3]))
# Out:
# 3
