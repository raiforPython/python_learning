# %% [markdown]
# <a href="https://colab.research.google.com/github/raiforPython/python_learning/blob/python%E8%AA%8D%E5%AE%9A%E5%9F%BA%E7%A4%8E%E8%A9%A6%E9%A8%93%E5%AF%BE%E7%AD%96/20260629.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = [1, 2, 3]
y = x
x = x + [4]
print(y)
# Out:
# [1, 2, 3]

# %%
def func(a, b=[]):
    b.append(a)
    return b

print(func(1))
print(func(2))
# Out:
# [1]
# [1, 2]

# %%
#間違えた、、、
x = {"a": 1, "b": 2}
y = x
x["a"] = 3
print(y["a"])
# Out:
# 3

# %%
for i in range(1, 5, 2):
    print(i, end=" ")
# Out:
# 1 3
