# %% [markdown]
# <a href="https://colab.research.google.com/github/raiforPython/python_learning/blob/python%E8%AA%8D%E5%AE%9A%E5%9F%BA%E7%A4%8E%E8%A9%A6%E9%A8%93%E5%AF%BE%E7%AD%96/20260702_%E3%83%87%E3%83%BC%E3%82%BF%E6%A7%8B%E9%80%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (1, 2, 3)
t[1] = 99
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1447/4048348176.py in <cell line: 0>()
#       1 t = (1, 2, 3)
# ----> 2 t[1] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %%
nums = [1, 2, 3, 4, 5]
result = [n * 2 for n in nums if n % 2 == 1]
print(result)
# Out:
# [2, 6, 10]

# %%
data = {"x": 10, "y": 20}
data.update({"y": 99, "z": 30})
result = "z" in data #キーが辞書内に存在するかどうかを確認
print(result)
print(data)
# Out:
# True
# {'x': 10, 'y': 99, 'z': 30}

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5}
result = a - b
print(result)
# Out:
# {1, 2}

# %%
t = (1, 2, 3)
lst = list(t)
lst.append(4)
result = tuple(lst)
print(result)
# Out:
# (1, 2, 3, 4)
