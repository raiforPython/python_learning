# %% [markdown]
# <a href="https://colab.research.google.com/github/raiforPython/python_learning/blob/chapter_7/7-4(2)_%E3%83%91%E3%83%83%E3%82%B1%E3%83%BC%E3%82%B8%E3%81%AE%E5%88%A9%E7%94%A8-.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# httpパッケージのclientモジュールを取り込む
import http.client

conn = http.client.HTTPConnection('www.python.org')

# %%
# httpパッケージのclientモジュールを取り込む（from利用）
from http import client
conn = client.HTTPConnection('www.python.org')

# %%
# httpパッケージのclientモジュールから関数だけを取り込む
from http.client import HTTPConnection
conn = HTTPConnection('www.python.org')
